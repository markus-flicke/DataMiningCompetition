# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

plt.rcParams['figure.figsize'] = (20, 8)   
plt.rcParams['figure.dpi'] = 72             
plt.rcParams['font.size'] = 16               
plt.rcParams['text.usetex'] = False

# %%
df = pd.concat([pd.read_csv('train_imputed.csv').drop('target', axis = 1), pd.read_csv('test_imputed.csv')], ignore_index = True)
train_df = pd.read_csv('train_imputed.csv')

# %% [markdown]
# ### Limit Balance
# * 23 /30000 limit balances were negative.
#     * What sense does this make? I have no clue

# %%
df[df.limit_balance < 0].shape
# Out:
# (23, 44)

# %%
plt.title('Positive Balances')
sns.distplot(df[df.limit_balance >=0].limit_balance)

# %%
import numpy as np
plt.title('Negative Balances')

sns.distplot(-np.log10(-df[df.limit_balance <0].limit_balance, where =  lambda x: x > 0))
plt.xlabel('-log10(abs(Limit Balance))')
# Out:
# Text(0.5, 0, '-log10(abs(Limit Balance))')
